# %% [markdown]
# <a href="https://colab.research.google.com/github/Dava619/DAVA-MUKHLIS/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile input_data.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     string namaSiswa;
#     int umur;
#
#     cout << "davamukhlissaputra (ganteng) : ";
#     cin >> namaSiswa;
#
#     cout << "15 tahun    : ";
#     cin >> umur;
#
#     cout << "\nHalo " << namaSiswa << ", ternyata kamu masih kecil ya, umurnya" << umur << " 15 tahun ya!" << endl;
#     return 0;
# }
# Out:
# Overwriting input_data.cpp

# %%
# !g++ input_data.cpp -o input_data

# %%
# !./input_data
# Out:
# davamukhlissaputra (orang ganteng) : dava
# 15 tahun    : 15
#
# Halo dava, ternyata kamu masih kecil ya, umurnya15 15 tahun ya!
